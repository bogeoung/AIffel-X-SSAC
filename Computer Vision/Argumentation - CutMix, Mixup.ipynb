# %% [markdown]
# ### 1. 데이터 불러오기

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import urllib3
urllib3.disable_warnings()
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %% [markdown]
# ### 2. Argumentation 적용

# %% [markdown]
# #### (1) flip

# %%
# 이미지를 변환하기 위한 전처리 함수
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, [224, 224])
    return tf.cast(image, tf.float32) / 255., label

# %%
# 좌우 대칭
def augment(image,label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    return image,label

# %% [markdown]
# #### (2) Cutmix

# %%
def get_clip_box(image_a, image_b,img_size=224):
    # image.shape = (height, width, channel)
    #print("get_clip")
    #image_size_x = image_a.shape[1]
    #image_size_y = image_a.shape[0]
    
    # get center of box
    x = tf.cast( tf.random.uniform([],0, img_size),tf.int32)
    y = tf.cast( tf.random.uniform([],0, img_size),tf.int32)

    # get width, height of box
    width = tf.cast(img_size * tf.math.sqrt(1-tf.random.uniform([],0,1)),tf.int32)
    height = tf.cast(img_size * tf.math.sqrt(1-tf.random.uniform([],0,1)),tf.int32)
    
    # clip box in image and get minmax bbox
    xa = tf.math.maximum(0, x-width//2)
    ya = tf.math.maximum(0, y-height//2)
    xb = tf.math.minimum(img_size, x+width//2)
    yb = tf.math.minimum(img_size, y+width//2)
    
    return xa, ya, xb, yb

# %%
# mix two images
def mix_2_images(image_a, image_b, xa, ya, xb, yb, img_size=224):
    #print("mix_2_images")
    #image_size_x = image_a.shape[1]
    #image_size_y = image_a.shape[0] 
    one = image_a[ya:yb,0:xa,:]
    two = image_b[ya:yb,xa:xb,:]
    three = image_a[ya:yb,xb:img_size,:]
    middle = tf.concat([one,two,three],axis=1)
    top = image_a[0:ya,:,:]
    bottom = image_a[yb:img_size,:,:]
    mixed_img = tf.concat([top, middle, bottom],axis=0)
    
    return mixed_img

# %%
# mix two labels
def mix_2_label(label_a, label_b, xa, ya, xb, yb, img_size=224, num_classes=120):
    #print("mix_2_label")
    #image_size_x = image_a.shape[1]
    #image_size_y = image_a.shape[0] 
    mixed_area = (xb-xa)*(yb-ya)
    total_area = img_size * img_size
    a = tf.cast(mixed_area/total_area, tf.float32)
    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_label = (1-a)*label_a + a*label_b
    return mixed_label

# %%
def cutmix(image, label, prob = 1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([],0, batch_size),tf.int32)
        image_b = image[j]
        label_b = label[j]
        xa, ya, xb, yb = get_clip_box(image_a, image_b)
        mixed_imgs.append(mix_2_images(image_a, image_b, xa, ya, xb, yb))
        mixed_labels.append(mix_2_label(label_a, label_b, xa, ya, xb, yb))

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs),(batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels),(batch_size, num_classes))
    return mixed_imgs, mixed_labels

# %% [markdown]
# #### (3) Mixup

# %%
# function for mixup
def mixup_2_images(image_a, image_b, label_a, label_b, num_classes=120):
    a = tf.random.uniform([],0,1)
    
    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_image= (1-a)*image_a + a*image_b
    mixed_label = (1-a)*label_a + a*label_b
    
    return mixed_image, mixed_label

# %%
def mixup(image, label, prob = 1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([],0, batch_size),tf.int32)
        image_b = image[j]
        label_b = label[j]
        mixed_img, mixed_label = mixup_2_images(image_a, image_b, label_a, label_b)
        mixed_imgs.append(mixed_img)
        mixed_labels.append(mixed_label)

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs),(batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels),(batch_size, num_classes))
    return mixed_imgs, mixed_labels

# %% [markdown]
# ---

# %%
def onehot(image, label, prob = 1.0, batch_size=16, img_size=224, num_classes=120):
    imgs = []
    labels = []
    for i in range(batch_size):
        imgs.append(image[i])
        labels.append(tf.one_hot(label[i], num_classes))
    imgs = tf.reshape(tf.stack(imgs), (batch_size, img_size, img_size, 3))
    return imgs, labels

# %%
# 데이터셋(ds)을 가공하는 메인함수
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16, with_aug=False, with_cutmix=False, with_mixup=False):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=2
    )
    if not is_test and with_aug:
        ds = ds.map(
            augment
        )
    ds = ds.batch(batch_size)
    
    if not is_test and with_cutmix:
        ds = ds.map(
            cutmix,
            num_parallel_calls=2
        )
        
    elif not is_test and with_mixup:
        ds = ds.map(
            mixup,
            num_parallel_calls = 2
        )
    else:
        ds = ds.map(
            onehot,
            num_parallel_calls = 2
        )
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %% [markdown]
# ### 3. 비교실험

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

ds_train_no_aug = apply_normalize_on_dataset(ds_train, with_aug=False)
ds_train_aug = apply_normalize_on_dataset(ds_train, with_aug=True)
ds_test = apply_normalize_on_dataset(ds_test, is_test = True)
ds_train_with_cutmix = apply_normalize_on_dataset(ds_train, with_aug=True, with_cutmix = True)
ds_train_with_mixup = apply_normalize_on_dataset(ds_train, with_aug=True, with_mixup = True)

# %%
num_classes = ds_info.features["label"].num_classes

resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation = 'softmax')
])

# %%
aug_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation = 'softmax')
])

# %%
cutmix_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation = 'softmax')
])

# %%
mixup_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation = 'softmax')
])

# %%
#EPOCH = 20  # Augentation 적용 효과를 확인하기 위해 필요한 epoch 수
EPOCH = 30

tf.random.set_seed(2020)

resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

aug_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

cutmix_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

mixup_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

history_resnet50_no_aug = resnet50.fit(
    ds_train_no_aug, # augmentation 적용하지 않은 데이터셋 사용
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

history_resnet50_aug = aug_resnet50.fit(
    ds_train_aug, # augmentation 적용한 데이터셋 사용
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

history_resnet50_with_cutmix = cutmix_resnet50.fit(
    ds_train_no_aug, # augmentation 적용하지 않은 데이터셋 사용
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

history_resnet50_with_mixup = mixup_resnet50.fit(
    ds_train_no_aug, # augmentation 적용하지 않은 데이터셋 사용
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/30
# 750/750 [==============================] - 111s 148ms/step - loss: 2.1826 - accuracy: 0.4505 - val_loss: 3.1807 - val_accuracy: 0.2364
# Epoch 2/30
# 750/750 [==============================] - 111s 148ms/step - loss: 0.7758 - accuracy: 0.7861 - val_loss: 1.0759 - val_accuracy: 0.6839
# Epoch 3/30
# 750/750 [==============================] - 111s 148ms/step - loss: 0.2723 - accuracy: 0.9379 - val_loss: 0.9922 - val_accuracy: 0.7108
# Epoch 4/30
# 750/750 [==============================] - 111s 148ms/step - loss: 0.0983 - accuracy: 0.9863 - val_loss: 0.9569 - val_accuracy: 0.7245
# Epoch 5/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0561 - accuracy: 0.9947 - val_loss: 0.9543 - val_accuracy: 0.7290
# Epoch 6/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0203 - accuracy: 0.9984 - val_loss: 0.9154 - val_accuracy: 0.7434
# Epoch 7/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0103 - accuracy: 0.9999 - val_loss: 0.9234 - val_accuracy: 0.7444
# Epoch 8/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.9314 - val_accuracy: 0.7451
# Epoch 9/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.9382 - val_accuracy: 0.7473
# Epoch 10/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0086 - accuracy: 0.9999 - val_loss: 0.9537 - val_accuracy: 0.7450
# Epoch 11/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.9616 - val_accuracy: 0.7457
# Epoch 12/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.9913 - val_accuracy: 0.7389
# Epoch 13/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0089 - accuracy: 0.9998 - val_loss: 0.9817 - val_accuracy: 0.7417
# Epoch 14/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.9789 - val_accuracy: 0.7456
# Epoch 15/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0042 - accuracy: 0.9998 - val_loss: 1.0262 - val_accuracy: 0.7325
# Epoch 16/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0103 - accuracy: 0.9994 - val_loss: 0.9926 - val_accuracy: 0.7444
# Epoch 17/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0108 - accuracy: 0.9987 - val_loss: 1.0418 - val_accuracy: 0.7355
# Epoch 18/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.9965 - val_accuracy: 0.7449
# Epoch 19/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.0050 - val_accuracy: 0.7453
# Epoch 20/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0037 - accuracy: 0.9999 - val_loss: 1.0022 - val_accuracy: 0.7448
# Epoch 21/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 1.0112 - val_accuracy: 0.7439
# Epoch 22/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0161 - val_accuracy: 0.7450
# Epoch 23/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.0207 - val_accuracy: 0.7438
# Epoch 24/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0217 - val_accuracy: 0.7443
# Epoch 25/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0249 - val_accuracy: 0.7469
# Epoch 26/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0287 - val_accuracy: 0.7455
# Epoch 27/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0346 - val_accuracy: 0.7455
# Epoch 28/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 1.0422 - val_accuracy: 0.7415
# Epoch 29/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 1.0333 - val_accuracy: 0.7452
# Epoch 30/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 1.0334 - val_accuracy: 0.7448
# Epoch 1/30
# 750/750 [==============================] - 111s 148ms/step - loss: 2.2302 - accuracy: 0.4415 - val_loss: 2.7394 - val_accuracy: 0.3060
# Epoch 2/30
# 750/750 [==============================] - 111s 148ms/step - loss: 0.9492 - accuracy: 0.7282 - val_loss: 1.1392 - val_accuracy: 0.6681
# Epoch 3/30
# 750/750 [==============================] - 111s 148ms/step - loss: 0.5495 - accuracy: 0.8438 - val_loss: 1.0380 - val_accuracy: 0.6974
# Epoch 4/30
# 750/750 [==============================] - 111s 148ms/step - loss: 0.3024 - accuracy: 0.9218 - val_loss: 1.0209 - val_accuracy: 0.7023
# Epoch 5/30
# 750/750 [==============================] - 111s 148ms/step - loss: 0.1916 - accuracy: 0.9576 - val_loss: 1.0322 - val_accuracy: 0.7085
# Epoch 6/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.1263 - accuracy: 0.9753 - val_loss: 1.1669 - val_accuracy: 0.6803
# Epoch 7/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0610 - accuracy: 0.9918 - val_loss: 0.9911 - val_accuracy: 0.7315
# Epoch 8/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0494 - accuracy: 0.9931 - val_loss: 0.9417 - val_accuracy: 0.7432
# Epoch 9/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0383 - accuracy: 0.9948 - val_loss: 0.9573 - val_accuracy: 0.7394
# Epoch 10/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0297 - accuracy: 0.9967 - val_loss: 0.9857 - val_accuracy: 0.7437
# Epoch 11/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0246 - accuracy: 0.9975 - val_loss: 0.9822 - val_accuracy: 0.7414
# Epoch 12/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0141 - accuracy: 0.9984 - val_loss: 0.9568 - val_accuracy: 0.7535
# Epoch 13/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0076 - accuracy: 0.9995 - val_loss: 0.9437 - val_accuracy: 0.7584
# Epoch 14/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0062 - accuracy: 0.9998 - val_loss: 0.9491 - val_accuracy: 0.7576
# Epoch 15/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0084 - accuracy: 0.9995 - val_loss: 0.9670 - val_accuracy: 0.7566
# Epoch 16/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0051 - accuracy: 0.9998 - val_loss: 0.9650 - val_accuracy: 0.7576
# Epoch 17/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0079 - accuracy: 0.9995 - val_loss: 0.9748 - val_accuracy: 0.7542
# Epoch 18/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0061 - accuracy: 0.9998 - val_loss: 0.9792 - val_accuracy: 0.7585
# Epoch 19/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0036 - accuracy: 0.9999 - val_loss: 0.9799 - val_accuracy: 0.7590
# Epoch 20/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0056 - accuracy: 0.9996 - val_loss: 0.9875 - val_accuracy: 0.7576
# Epoch 21/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0033 - accuracy: 0.9998 - val_loss: 0.9808 - val_accuracy: 0.7563
# Epoch 22/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0053 - accuracy: 0.9997 - val_loss: 0.9999 - val_accuracy: 0.7566
# Epoch 23/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 1.0010 - val_accuracy: 0.7599
# Epoch 24/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0049 - accuracy: 0.9997 - val_loss: 1.0134 - val_accuracy: 0.7582
# Epoch 25/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0107 - val_accuracy: 0.7596
# Epoch 26/30
# 750/750 [==============================] - 111s 147ms/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 1.0165 - val_accuracy: 0.7599
# Epoch 27/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.0131 - val_accuracy: 0.7601
# Epoch 28/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0178 - val_accuracy: 0.7593
# Epoch 29/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0215 - val_accuracy: 0.7591
# Epoch 30/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 1.0281 - val_accuracy: 0.7551
# Epoch 1/30
# 750/750 [==============================] - 110s 147ms/step - loss: 2.2196 - accuracy: 0.4439 - val_loss: 3.4202 - val_accuracy: 0.1939
# Epoch 2/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.7716 - accuracy: 0.7838 - val_loss: 1.2368 - val_accuracy: 0.6462
# Epoch 3/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.2890 - accuracy: 0.9332 - val_loss: 1.0094 - val_accuracy: 0.7051
# Epoch 4/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0943 - accuracy: 0.9870 - val_loss: 0.9406 - val_accuracy: 0.7267
# Epoch 5/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0378 - accuracy: 0.9975 - val_loss: 0.9248 - val_accuracy: 0.7343
# Epoch 6/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0158 - accuracy: 0.9992 - val_loss: 0.9215 - val_accuracy: 0.7399
# Epoch 7/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.9342 - val_accuracy: 0.7368
# Epoch 8/30
# 750/750 [==============================] - 110s 147ms/step - loss: 0.0083 - accuracy: 0.9999 - val_loss: 0.9617 - val_accuracy: 0.7334
# Epoch 9/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0164 - accuracy: 0.9992 - val_loss: 0.9753 - val_accuracy: 0.7324
# Epoch 10/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0078 - accuracy: 0.9998 - val_loss: 0.9652 - val_accuracy: 0.7375
# Epoch 11/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0108 - accuracy: 0.9997 - val_loss: 1.0005 - val_accuracy: 0.7327
# Epoch 12/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0052 - accuracy: 0.9998 - val_loss: 0.9864 - val_accuracy: 0.7355
# Epoch 13/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.9846 - val_accuracy: 0.7394
# Epoch 14/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0035 - val_accuracy: 0.7357
# Epoch 15/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0093 - accuracy: 0.9998 - val_loss: 0.9979 - val_accuracy: 0.7357
# Epoch 16/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0058 - accuracy: 0.9995 - val_loss: 0.9967 - val_accuracy: 0.7397
# Epoch 17/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0055 - accuracy: 0.9998 - val_loss: 1.0019 - val_accuracy: 0.7404
# Epoch 18/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0031 - val_accuracy: 0.7407
# Epoch 19/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0092 - val_accuracy: 0.7401
# Epoch 20/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0175 - val_accuracy: 0.7386
# Epoch 21/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0213 - val_accuracy: 0.7397
# Epoch 22/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0044 - accuracy: 0.9999 - val_loss: 1.0356 - val_accuracy: 0.7344
# Epoch 23/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 1.0301 - val_accuracy: 0.7365
# Epoch 24/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0293 - val_accuracy: 0.7379
# Epoch 25/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 1.0488 - val_accuracy: 0.7368
# Epoch 26/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0051 - accuracy: 0.9998 - val_loss: 1.0417 - val_accuracy: 0.7343
# Epoch 27/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0423 - val_accuracy: 0.7351
# Epoch 28/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0044 - accuracy: 0.9998 - val_loss: 1.0437 - val_accuracy: 0.7371
# Epoch 29/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0049 - accuracy: 0.9996 - val_loss: 1.0508 - val_accuracy: 0.7381
# Epoch 30/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.0537 - val_accuracy: 0.7358
# Epoch 1/30
# 750/750 [==============================] - 110s 147ms/step - loss: 2.1863 - accuracy: 0.4498 - val_loss: 3.3998 - val_accuracy: 0.2100
# Epoch 2/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.7704 - accuracy: 0.7806 - val_loss: 1.1114 - val_accuracy: 0.6747
# Epoch 3/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.2921 - accuracy: 0.9310 - val_loss: 1.0479 - val_accuracy: 0.7024
# Epoch 4/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.1134 - accuracy: 0.9826 - val_loss: 0.9626 - val_accuracy: 0.7238
# Epoch 5/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0518 - accuracy: 0.9962 - val_loss: 0.9299 - val_accuracy: 0.7400
# Epoch 6/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0318 - accuracy: 0.9977 - val_loss: 0.9334 - val_accuracy: 0.7462
# Epoch 7/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0147 - accuracy: 0.9990 - val_loss: 0.9208 - val_accuracy: 0.7483
# Epoch 8/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0153 - accuracy: 0.9991 - val_loss: 0.9456 - val_accuracy: 0.7409
# Epoch 9/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0135 - accuracy: 0.9989 - val_loss: 0.9541 - val_accuracy: 0.7437
# Epoch 10/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0062 - accuracy: 0.9997 - val_loss: 0.9489 - val_accuracy: 0.7450
# Epoch 11/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.9616 - val_accuracy: 0.7469
# Epoch 12/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.9726 - val_accuracy: 0.7457
# Epoch 13/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0066 - accuracy: 0.9997 - val_loss: 1.0031 - val_accuracy: 0.7428
# Epoch 14/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0057 - accuracy: 0.9998 - val_loss: 0.9942 - val_accuracy: 0.7417
# Epoch 15/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0071 - accuracy: 0.9994 - val_loss: 0.9952 - val_accuracy: 0.7415
# Epoch 16/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0045 - accuracy: 0.9998 - val_loss: 0.9961 - val_accuracy: 0.7458
# Epoch 17/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 1.0013 - val_accuracy: 0.7456
# Epoch 18/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0043 - accuracy: 0.9999 - val_loss: 1.0097 - val_accuracy: 0.7460
# Epoch 19/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0047 - accuracy: 0.9998 - val_loss: 1.0096 - val_accuracy: 0.7470
# Epoch 20/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0021 - accuracy: 0.9999 - val_loss: 1.0184 - val_accuracy: 0.7449
# Epoch 21/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.0239 - val_accuracy: 0.7456
# Epoch 22/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0225 - val_accuracy: 0.7453
# Epoch 23/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0341 - val_accuracy: 0.7413
# Epoch 24/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0029 - accuracy: 0.9999 - val_loss: 1.0341 - val_accuracy: 0.7435
# Epoch 25/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 1.0387 - val_accuracy: 0.7449
# Epoch 26/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0024 - accuracy: 0.9999 - val_loss: 1.0395 - val_accuracy: 0.7436
# Epoch 27/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0026 - accuracy: 0.9999 - val_loss: 1.0446 - val_accuracy: 0.7424
# Epoch 28/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 1.0359 - val_accuracy: 0.7470
# Epoch 29/30
# 750/750 [==============================] - 110s 146ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.0437 - val_accuracy: 0.7465
# Epoch 30/30
# 750/750 [==============================] - 110s 146ms/step - loss: 9.3506e-04 - accuracy: 1.0000 - val_loss: 1.0458 - val_accuracy: 0.7465

# %%
plt.plot(history_resnet50_no_aug.history['val_accuracy'], 'r')
plt.plot(history_resnet50_aug.history['val_accuracy'], 'b')
plt.plot(history_resnet50_with_cutmix.history['val_accuracy'], 'g')
plt.plot(history_resnet50_with_mixup.history['val_accuracy'], 'y')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['No Augmentation', 'With Augmentation'], loc='upper left')
plt.show()

# %%
plt.plot(history_resnet50_no_aug.history['val_accuracy'], 'r')
plt.plot(history_resnet50_aug.history['val_accuracy'], 'b')
plt.plot(history_resnet50_with_cutmix.history['val_accuracy'], 'g')
plt.plot(history_resnet50_with_mixup.history['val_accuracy'], 'y')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['No Augmentation', 'With Augmentation', 'Aug + Cutmix', 'Aug + Mixup'], loc='upper left')
plt.grid(True)
plt.ylim(0.72, 0.76)
plt.show()
